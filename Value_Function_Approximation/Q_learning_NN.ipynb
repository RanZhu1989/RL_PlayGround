# %%
import numpy as np
import gymnasium as gym
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# In this notebook, we will *naively* implement a neural network to approximate the Q function. Since value function approximation can handle large state spaces (even continuous). We use the *CartPole* environment with a continuous state space.
#
# The core idea of Q learning with Q function approximation is to learn a Q function $\hat{q}(s,a,w)$ (*with optimal policy*) that approximates the true Q function. To achieve this, we use a neural network to approximate the Q function, and the function approximation problem turn into a optimization problem. We will use the mean squared error (MSE) as the loss function. The objective function is given by
#
# \begin{equation}
# J=\mathbb{E}\left[\left(R+\gamma \max _{a \in \mathcal{A}\left(S^{\prime}\right)} \hat{q}\left(S^{\prime}, a, w\right)-\hat{q}(S, A, w)\right)^2\right]
# \end{equation}
#
# Using gradient descent, we can update the weights of the neural network of Q function by
#
# \begin{equation}
# \nabla_w J=\mathbb{E}\left[\left(R+\gamma \max_{a \in \mathcal{A}\left(S^{\prime}\right)} \hat{q}\left(S^{\prime}, a, w\right)-\hat{q}(S, A, w)\right) \nabla_w \hat{q}(S, A, w)\right]
# \end{equation}
#
# \begin{equation}
# w \gets w - \alpha_t \left(r_{t+1}+\gamma \max_{a^{\prime} \in \mathcal{A}(s_{t+1})} \hat{q}\left(s_{t+1}, a^{\prime}, w\right)-\hat{q}(s_t, a_t, w)\right) \nabla_{w} \hat{q}(s_t, a_t, w)
# \end{equation}
#
# Thanks to the *autogradient* feature of **PyTorch**, we can easily implement the above progress (i.e., solving the optimization problem).
#
# Finally, we update the policy using the learnt Q function. Note that the exploitation part in such $\varepsilon$-greedy policy can be act as the target policy.
#
# \begin{equation}
# \begin{aligned}
# & \pi_{t+1}\left(a \mid s_t\right)=1-\frac{\varepsilon}{|\mathcal{A}(s)|}(|\mathcal{A}(s)|-1) \text { if } a=\arg \max _{a \in \mathcal{A}\left(s_t\right)} \hat{q}\left(s_t, a, w_{t+1}\right) \\
# & \pi_{t+1}\left(a \mid s_t\right)=\frac{\varepsilon}{|\mathcal{A}(s)|} \text { otherwise }
# \end{aligned}
# \end{equation}

# %%
class QNN_Agent():
    """ Since the discrete actions have been redefined as {0,1} by env, we can simply represent the action by a number. """
    
    def __init__(self,
                 Q_func:torch.nn.Module,
                 action_dim:int,
                 optimizer:torch.optim.Optimizer,
                 epsilon:float = 0.1,
                 gamma:float = 0.9,
                 device:torch.device = torch.device("cpu")
                 ) -> None:
        self.device = device
        self.action_dim = action_dim
        
        self.Q_func = Q_func
        self.criteria = torch.nn.MSELoss()
        self.optimizer = optimizer
        
        self.epsilon = epsilon
        self.gamma = gamma

    def get_target_action(self,obs:np.ndarray) -> int:
        """The input of nn must be a tensor. 
            Here, the input data of the agent is numpy arrays, so we need to convert it to tensor first """
        obs = torch.tensor(obs,dtype=torch.float32).to(self.device)
        Q_list = self.Q_func(obs)
        
        """The output of nn is a tensor, so we need to convert it to numpy array and then to int type"""
        action = torch.argmax(Q_list).item()
        
        return action

    def get_behavior_action(self,obs:np.ndarray) -> int:
        if np.random.uniform(0,1) < self.epsilon:
            action = np.random.choice(self.action_dim)
        else:
            action = self.get_target_action(obs)
            
        return action
    
    def Q_star_approximation(self,
                             obs:np.ndarray,
                             action:int,
                             reward:float,
                             next_obs:np.ndarray,
                             done:bool) -> float:
        
        obs = torch.tensor(obs,dtype=torch.float32).to(self.device)
        next_obs = torch.tensor(next_obs,dtype=torch.float32).to(self.device)
        current_Q = self.Q_func(obs)[action]
        TD_target = reward + (1-float(done)) * self.gamma * self.Q_func(next_obs).max()
        loss = self.criteria(current_Q,TD_target)
        # Now, we directly use gradient descent to optimize the loss
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %% [markdown]
# Here, we use a simple MLP with 2 hidden layers to approximate the Q function.

# %%
class Q_Network(torch.nn.Module):
    """You can define your own network structure here."""
    def __init__(self,obs_dim:int,action_dim) -> None:
        super(Q_Network,self).__init__()
        self.fc1 = torch.nn.Linear(obs_dim,64)
        self.fc2 = torch.nn.Linear(64,action_dim)
            
    def forward(self,x:torch.Tensor) -> torch.Tensor:
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        
        return x

# %%
class TrainManager():
    def __init__(self,
                 env:gym.Env,
                 episode_num:int = 1000,
                 lr:float = 0.001,
                 gamma:float = 0.9,
                 epsilon:float = 0.1,
                 seed = 0 # To compare the performance of different algorithms, we need to fix the random seed
                 ) -> None:
        
        """Set seeds"""
        self.seed = seed
        np.random.seed(self.seed)
        torch.manual_seed(self.seed)       
        torch.backends.cudnn.deterministic = True
        
        """The device is automatically selected according to the availability of GPU"""
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        """if you want to use CPU, you can use the code below"""
        # self.device = torch.device("cpu")
        
        self.env = env
        self.episode_num = episode_num
        obs_dim = gym.spaces.utils.flatdim(env.observation_space) 
        action_dim = env.action_space.n 
        Q_func = Q_Network(obs_dim,action_dim).to(self.device)
        optimizer = torch.optim.Adam(Q_func.parameters(),lr=lr)
        self.agent = QNN_Agent(Q_func = Q_func,
                               action_dim = action_dim,
                               optimizer = optimizer,
                               epsilon = epsilon,
                               gamma = gamma,
                               device = self.device)
        
        """Here, we use a numpy array to store the total reward of each episode"""
        self.episode_total_rewards = np.zeros(episode_num)
        self.index_episode = 0  
    
    def train_episode(self,is_render:bool=False) -> float:
        total_reward = 0 
        obs,_ = self.env.reset(seed=self.seed) 
        while True:
            action = self.agent.get_behavior_action(obs) 
            next_obs, reward, terminated, truncated, _ = self.env.step(action) 
            done = terminated or truncated
            total_reward += reward 
            self.agent.Q_star_approximation(obs,action,reward,next_obs,done)
            obs = next_obs
            if is_render:
                self.env.render()
                                
            if done:
                self.episode_total_rewards[self.index_episode] = total_reward
                self.index_episode += 1
                break
            
        return total_reward       

    def test_episode(self) -> float:
        total_reward = 0 
        obs,_ = self.env.reset(seed=self.seed) # For this environment, the returned obsevation is a numpy.ndarray
        while True:
            action = self.agent.get_target_action(obs) 
            next_obs, reward, terminated, truncated, _= self.env.step(action) 
            done = terminated or truncated  
            obs = next_obs
            total_reward += reward
            self.env.render()
            if done: break
            
        return total_reward
            
    def train(self) -> None:     
        for e in range(self.episode_num):
            episode_reward = self.train_episode()
            print('Episode %s: Total Reward = %.2f'%(e,episode_reward)) 
            
            # if e%100 == 0: 
            #     test_reward = self.test_episode()
            #     print('Test Total Reward = %.2f'%(test_reward))
    
    """-------------------------------------For Plotting-------------------------------------------------------- """
    def plotting(self,smoothing_window:int = 100) -> None:    
        """ Plot the episode reward over time. """
        fig = plt.figure(figsize=(10,5))
        plt.plot(self.episode_total_rewards,label="Episode Reward")
        # Use rolling mean to smooth the curve
        rewards_smoothed = pd.Series(self.episode_total_rewards).rolling(smoothing_window, min_periods=smoothing_window).mean()
        plt.plot(rewards_smoothed,label="Episode Reward (Smoothed)")
        plt.xlabel('Episode')
        plt.ylabel('Episode Reward')
        plt.title("Episode Reward over Time")
        plt.legend()
        plt.show()

# %%
if __name__ == "__main__":
    env = gym.make('CartPole-v0')
    Manger = TrainManager(env = env,
                        episode_num = 1000,
                        lr = 0.001,
                        gamma = 0.9,
                        epsilon = 0.1
                        )
    Manger.train()
    Manger.plotting() # The following curve is plotted used cuda
# Out:
# c:\Users\gemin\miniconda3\envs\pytorch\lib\site-packages\gymnasium\envs\registration.py:523: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# Episode 0: Total Reward = 11.00
# Episode 1: Total Reward = 12.00
# Episode 2: Total Reward = 11.00
# Episode 3: Total Reward = 11.00
# Episode 4: Total Reward = 11.00
# Episode 5: Total Reward = 11.00
# Episode 6: Total Reward = 12.00
# Episode 7: Total Reward = 11.00
# Episode 8: Total Reward = 11.00
# Episode 9: Total Reward = 11.00
# Episode 10: Total Reward = 11.00
# Episode 11: Total Reward = 11.00
# Episode 12: Total Reward = 11.00
# Episode 13: Total Reward = 11.00
# Episode 14: Total Reward = 14.00
# Episode 15: Total Reward = 12.00
# Episode 16: Total Reward = 11.00
# Episode 17: Total Reward = 11.00
# Episode 18: Total Reward = 11.00
# Episode 19: Total Reward = 11.00
# Episode 20: Total Reward = 13.00
# Episode 21: Total Reward = 12.00
# Episode 22: Total Reward = 13.00
# Episode 23: Total Reward = 12.00
# Episode 24: Total Reward = 11.00
# Episode 25: Total Reward = 11.00
# Episode 26: Total Reward = 12.00
# Episode 27: Total Reward = 11.00
# Episode 28: Total Reward = 11.00
# Episode 29: Total Reward = 11.00
# Episode 30: Total Reward = 12.00
# Episode 31: Total Reward = 11.00
# Episode 32: Total Reward = 11.00
# Episode 33: Total Reward = 11.00
# Episode 34: Total Reward = 13.00
# Episode 35: Total Reward = 11.00
# Episode 36: Total Reward = 11.00
# Episode 37: Total Reward = 13.00
# Episode 38: Total Reward = 11.00
# Episode 39: Total Reward = 11.00
# Episode 40: Total Reward = 11.00
# Episode 41: Total Reward = 11.00
# Episode 42: Total Reward = 11.00
# Episode 43: Total Reward = 11.00
# Episode 44: Total Reward = 13.00
# Episode 45: Total Reward = 11.00
# Episode 46: Total Reward = 11.00
# Episode 47: Total Reward = 11.00
# Episode 48: Total Reward = 11.00
# Episode 49: Total Reward = 11.00
# Episode 50: Total Reward = 13.00
# Episode 51: Total Reward = 11.00
# Episode 52: Total Reward = 11.00
# Episode 53: Total Reward = 11.00
# Episode 54: Total Reward = 11.00
# Episode 55: Total Reward = 12.00
# Episode 56: Total Reward = 11.00
# Episode 57: Total Reward = 12.00
# Episode 58: Total Reward = 11.00
# Episode 59: Total Reward = 14.00
# Episode 60: Total Reward = 11.00
# Episode 61: Total Reward = 11.00
# Episode 62: Total Reward = 11.00
# Episode 63: Total Reward = 12.00
# Episode 64: Total Reward = 11.00
# Episode 65: Total Reward = 11.00
# Episode 66: Total Reward = 11.00
# Episode 67: Total Reward = 11.00
# Episode 68: Total Reward = 11.00
# Episode 69: Total Reward = 11.00
# Episode 70: Total Reward = 15.00
# Episode 71: Total Reward = 11.00
# Episode 72: Total Reward = 11.00
# Episode 73: Total Reward = 11.00
# Episode 74: Total Reward = 11.00
# Episode 75: Total Reward = 11.00
# Episode 76: Total Reward = 12.00
# Episode 77: Total Reward = 11.00
# Episode 78: Total Reward = 11.00
# Episode 79: Total Reward = 11.00
# Episode 80: Total Reward = 11.00
# Episode 81: Total Reward = 13.00
# Episode 82: Total Reward = 11.00
# Episode 83: Total Reward = 18.00
# Episode 84: Total Reward = 13.00
# Episode 85: Total Reward = 12.00
# Episode 86: Total Reward = 14.00
# Episode 87: Total Reward = 11.00
# Episode 88: Total Reward = 11.00
# Episode 89: Total Reward = 11.00
# Episode 90: Total Reward = 11.00
# Episode 91: Total Reward = 11.00
# Episode 92: Total Reward = 12.00
# Episode 93: Total Reward = 12.00
# Episode 94: Total Reward = 11.00
# Episode 95: Total Reward = 11.00
# Episode 96: Total Reward = 11.00
# Episode 97: Total Reward = 11.00
# Episode 98: Total Reward = 11.00
# Episode 99: Total Reward = 11.00
# Episode 100: Total Reward = 13.00
# Episode 101: Total Reward = 11.00
# Episode 102: Total Reward = 13.00
# Episode 103: Total Reward = 12.00
# Episode 104: Total Reward = 11.00
# Episode 105: Total Reward = 13.00
# Episode 106: Total Reward = 11.00
# Episode 107: Total Reward = 11.00
# Episode 108: Total Reward = 12.00
# Episode 109: Total Reward = 12.00
# Episode 110: Total Reward = 11.00
# Episode 111: Total Reward = 12.00
# Episode 112: Total Reward = 13.00
# Episode 113: Total Reward = 34.00
# Episode 114: Total Reward = 8.00
# Episode 115: Total Reward = 9.00
# Episode 116: Total Reward = 8.00
# Episode 117: Total Reward = 46.00
# Episode 118: Total Reward = 19.00
# Episode 119: Total Reward = 16.00
# Episode 120: Total Reward = 13.00
# Episode 121: Total Reward = 13.00
# Episode 122: Total Reward = 11.00
# Episode 123: Total Reward = 11.00
# Episode 124: Total Reward = 11.00
# Episode 125: Total Reward = 11.00
# Episode 126: Total Reward = 12.00
# Episode 127: Total Reward = 11.00
# Episode 128: Total Reward = 11.00
# Episode 129: Total Reward = 14.00
# Episode 130: Total Reward = 11.00
# Episode 131: Total Reward = 11.00
# Episode 132: Total Reward = 11.00
# Episode 133: Total Reward = 14.00
# Episode 134: Total Reward = 11.00
# Episode 135: Total Reward = 11.00
# Episode 136: Total Reward = 11.00
# Episode 137: Total Reward = 11.00
# Episode 138: Total Reward = 15.00
# Episode 139: Total Reward = 20.00
# Episode 140: Total Reward = 30.00
# Episode 141: Total Reward = 105.00
# Episode 142: Total Reward = 14.00
# Episode 143: Total Reward = 10.00
# Episode 144: Total Reward = 8.00
# Episode 145: Total Reward = 9.00
# Episode 146: Total Reward = 9.00
# Episode 147: Total Reward = 8.00
# Episode 148: Total Reward = 8.00
# Episode 149: Total Reward = 8.00
# Episode 150: Total Reward = 8.00
# Episode 151: Total Reward = 8.00
# Episode 152: Total Reward = 10.00
# Episode 153: Total Reward = 9.00
# Episode 154: Total Reward = 8.00
# Episode 155: Total Reward = 10.00
# Episode 156: Total Reward = 8.00
# Episode 157: Total Reward = 8.00
# Episode 158: Total Reward = 8.00
# Episode 159: Total Reward = 10.00
# Episode 160: Total Reward = 10.00
# Episode 161: Total Reward = 13.00
# Episode 162: Total Reward = 77.00
# Episode 163: Total Reward = 11.00
# Episode 164: Total Reward = 11.00
# Episode 165: Total Reward = 11.00
# Episode 166: Total Reward = 11.00
# Episode 167: Total Reward = 12.00
# Episode 168: Total Reward = 11.00
# Episode 169: Total Reward = 11.00
# Episode 170: Total Reward = 11.00
# Episode 171: Total Reward = 11.00
# Episode 172: Total Reward = 12.00
# Episode 173: Total Reward = 11.00
# Episode 174: Total Reward = 12.00
# Episode 175: Total Reward = 11.00
# Episode 176: Total Reward = 11.00
# Episode 177: Total Reward = 11.00
# Episode 178: Total Reward = 11.00
# Episode 179: Total Reward = 11.00
# Episode 180: Total Reward = 11.00
# Episode 181: Total Reward = 12.00
# Episode 182: Total Reward = 12.00
# Episode 183: Total Reward = 11.00
# Episode 184: Total Reward = 12.00
# Episode 185: Total Reward = 12.00
# Episode 186: Total Reward = 12.00
# Episode 187: Total Reward = 21.00
# Episode 188: Total Reward = 27.00
# Episode 189: Total Reward = 44.00
# Episode 190: Total Reward = 40.00
# Episode 191: Total Reward = 68.00
# Episode 192: Total Reward = 47.00
# Episode 193: Total Reward = 38.00
# Episode 194: Total Reward = 37.00
# Episode 195: Total Reward = 70.00
# Episode 196: Total Reward = 51.00
# Episode 197: Total Reward = 31.00
# Episode 198: Total Reward = 21.00
# Episode 199: Total Reward = 25.00
# Episode 200: Total Reward = 26.00
# Episode 201: Total Reward = 44.00
# Episode 202: Total Reward = 48.00
# Episode 203: Total Reward = 30.00
# Episode 204: Total Reward = 27.00
# Episode 205: Total Reward = 42.00
# Episode 206: Total Reward = 103.00
# Episode 207: Total Reward = 36.00
# Episode 208: Total Reward = 62.00
# Episode 209: Total Reward = 41.00
# Episode 210: Total Reward = 41.00
# Episode 211: Total Reward = 45.00
# Episode 212: Total Reward = 29.00
# Episode 213: Total Reward = 43.00
# Episode 214: Total Reward = 35.00
# Episode 215: Total Reward = 31.00
# Episode 216: Total Reward = 46.00
# Episode 217: Total Reward = 25.00
# Episode 218: Total Reward = 22.00
# Episode 219: Total Reward = 22.00
# Episode 220: Total Reward = 24.00
# Episode 221: Total Reward = 20.00
# Episode 222: Total Reward = 18.00
# Episode 223: Total Reward = 19.00
# Episode 224: Total Reward = 17.00
# Episode 225: Total Reward = 15.00
# Episode 226: Total Reward = 16.00
# Episode 227: Total Reward = 16.00
# Episode 228: Total Reward = 18.00
# Episode 229: Total Reward = 40.00
# Episode 230: Total Reward = 109.00
# Episode 231: Total Reward = 59.00
# Episode 232: Total Reward = 46.00
# Episode 233: Total Reward = 32.00
# Episode 234: Total Reward = 47.00
# Episode 235: Total Reward = 26.00
# Episode 236: Total Reward = 40.00
# Episode 237: Total Reward = 26.00
# Episode 238: Total Reward = 22.00
# Episode 239: Total Reward = 23.00
# Episode 240: Total Reward = 29.00
# Episode 241: Total Reward = 36.00
# Episode 242: Total Reward = 30.00
# Episode 243: Total Reward = 30.00
# Episode 244: Total Reward = 44.00
# Episode 245: Total Reward = 37.00
# Episode 246: Total Reward = 39.00
# Episode 247: Total Reward = 43.00
# Episode 248: Total Reward = 45.00
# Episode 249: Total Reward = 31.00
# Episode 250: Total Reward = 25.00
# Episode 251: Total Reward = 30.00
# Episode 252: Total Reward = 49.00
# Episode 253: Total Reward = 35.00
# Episode 254: Total Reward = 27.00
# Episode 255: Total Reward = 25.00
# Episode 256: Total Reward = 25.00
# Episode 257: Total Reward = 38.00
# Episode 258: Total Reward = 38.00
# Episode 259: Total Reward = 40.00
# Episode 260: Total Reward = 40.00
# Episode 261: Total Reward = 37.00
# Episode 262: Total Reward = 29.00
# Episode 263: Total Reward = 32.00
# Episode 264: Total Reward = 55.00
# Episode 265: Total Reward = 20.00
# Episode 266: Total Reward = 18.00
# Episode 267: Total Reward = 21.00
# Episode 268: Total Reward = 35.00
# Episode 269: Total Reward = 51.00
# Episode 270: Total Reward = 42.00
# Episode 271: Total Reward = 48.00
# Episode 272: Total Reward = 41.00
# Episode 273: Total Reward = 24.00
# Episode 274: Total Reward = 21.00
# Episode 275: Total Reward = 16.00
# Episode 276: Total Reward = 16.00
# Episode 277: Total Reward = 44.00
# Episode 278: Total Reward = 68.00
# Episode 279: Total Reward = 50.00
# Episode 280: Total Reward = 47.00
# Episode 281: Total Reward = 53.00
# Episode 282: Total Reward = 57.00
# Episode 283: Total Reward = 53.00
# Episode 284: Total Reward = 51.00
# Episode 285: Total Reward = 26.00
# Episode 286: Total Reward = 25.00
# Episode 287: Total Reward = 35.00
# Episode 288: Total Reward = 36.00
# Episode 289: Total Reward = 27.00
# Episode 290: Total Reward = 25.00
# Episode 291: Total Reward = 26.00
# Episode 292: Total Reward = 46.00
# Episode 293: Total Reward = 40.00
# Episode 294: Total Reward = 34.00
# Episode 295: Total Reward = 31.00
# Episode 296: Total Reward = 36.00
# Episode 297: Total Reward = 45.00
# Episode 298: Total Reward = 26.00
# Episode 299: Total Reward = 30.00
# Episode 300: Total Reward = 32.00
# Episode 301: Total Reward = 30.00
# Episode 302: Total Reward = 36.00
# Episode 303: Total Reward = 29.00
# Episode 304: Total Reward = 25.00
# Episode 305: Total Reward = 24.00
# Episode 306: Total Reward = 24.00
# Episode 307: Total Reward = 29.00
# Episode 308: Total Reward = 41.00
# Episode 309: Total Reward = 37.00
# Episode 310: Total Reward = 34.00
# Episode 311: Total Reward = 34.00
# Episode 312: Total Reward = 32.00
# Episode 313: Total Reward = 35.00
# Episode 314: Total Reward = 39.00
# Episode 315: Total Reward = 39.00
# Episode 316: Total Reward = 35.00
# Episode 317: Total Reward = 42.00
# Episode 318: Total Reward = 44.00
# Episode 319: Total Reward = 93.00
# Episode 320: Total Reward = 42.00
# Episode 321: Total Reward = 35.00
# Episode 322: Total Reward = 40.00
# Episode 323: Total Reward = 35.00
# Episode 324: Total Reward = 28.00
# Episode 325: Total Reward = 38.00
# Episode 326: Total Reward = 42.00
# Episode 327: Total Reward = 45.00
# Episode 328: Total Reward = 49.00
# Episode 329: Total Reward = 49.00
# Episode 330: Total Reward = 43.00
# Episode 331: Total Reward = 34.00
# Episode 332: Total Reward = 49.00
# Episode 333: Total Reward = 49.00
# Episode 334: Total Reward = 53.00
# Episode 335: Total Reward = 47.00
# Episode 336: Total Reward = 46.00
# Episode 337: Total Reward = 50.00
# Episode 338: Total Reward = 53.00
# Episode 339: Total Reward = 43.00
# Episode 340: Total Reward = 45.00
# Episode 341: Total Reward = 52.00
# Episode 342: Total Reward = 56.00
# Episode 343: Total Reward = 54.00
# Episode 344: Total Reward = 52.00
# Episode 345: Total Reward = 53.00
# Episode 346: Total Reward = 55.00
# Episode 347: Total Reward = 64.00
# Episode 348: Total Reward = 63.00
# Episode 349: Total Reward = 111.00
# Episode 350: Total Reward = 91.00
# Episode 351: Total Reward = 118.00
# Episode 352: Total Reward = 17.00
# Episode 353: Total Reward = 12.00
# Episode 354: Total Reward = 13.00
# Episode 355: Total Reward = 98.00
# Episode 356: Total Reward = 70.00
# Episode 357: Total Reward = 66.00
# Episode 358: Total Reward = 73.00
# Episode 359: Total Reward = 51.00
# Episode 360: Total Reward = 58.00
# Episode 361: Total Reward = 75.00
# Episode 362: Total Reward = 59.00
# Episode 363: Total Reward = 60.00
# Episode 364: Total Reward = 66.00
# Episode 365: Total Reward = 62.00
# Episode 366: Total Reward = 58.00
# Episode 367: Total Reward = 71.00
# Episode 368: Total Reward = 88.00
# Episode 369: Total Reward = 72.00
# Episode 370: Total Reward = 62.00
# Episode 371: Total Reward = 64.00
# Episode 372: Total Reward = 102.00
# Episode 373: Total Reward = 94.00
# Episode 374: Total Reward = 101.00
# Episode 375: Total Reward = 101.00
# Episode 376: Total Reward = 132.00
# Episode 377: Total Reward = 9.00
# Episode 378: Total Reward = 8.00
# Episode 379: Total Reward = 8.00
# Episode 380: Total Reward = 8.00
# Episode 381: Total Reward = 8.00
# Episode 382: Total Reward = 8.00
# Episode 383: Total Reward = 8.00
# Episode 384: Total Reward = 8.00
# Episode 385: Total Reward = 10.00
# Episode 386: Total Reward = 8.00
# Episode 387: Total Reward = 8.00
# Episode 388: Total Reward = 8.00
# Episode 389: Total Reward = 8.00
# Episode 390: Total Reward = 8.00
# Episode 391: Total Reward = 8.00
# Episode 392: Total Reward = 8.00
# Episode 393: Total Reward = 9.00
# Episode 394: Total Reward = 8.00
# Episode 395: Total Reward = 8.00
# Episode 396: Total Reward = 8.00
# Episode 397: Total Reward = 8.00
# Episode 398: Total Reward = 8.00
# Episode 399: Total Reward = 11.00
# Episode 400: Total Reward = 8.00
# Episode 401: Total Reward = 8.00
# Episode 402: Total Reward = 8.00
# Episode 403: Total Reward = 8.00
# Episode 404: Total Reward = 8.00
# Episode 405: Total Reward = 8.00
# Episode 406: Total Reward = 9.00
# Episode 407: Total Reward = 36.00
# Episode 408: Total Reward = 11.00
# Episode 409: Total Reward = 12.00
# Episode 410: Total Reward = 11.00
# Episode 411: Total Reward = 11.00
# Episode 412: Total Reward = 11.00
# Episode 413: Total Reward = 11.00
# Episode 414: Total Reward = 12.00
# Episode 415: Total Reward = 11.00
# Episode 416: Total Reward = 11.00
# Episode 417: Total Reward = 12.00
# Episode 418: Total Reward = 11.00
# Episode 419: Total Reward = 11.00
# Episode 420: Total Reward = 13.00
# Episode 421: Total Reward = 11.00
# Episode 422: Total Reward = 11.00
# Episode 423: Total Reward = 11.00
# Episode 424: Total Reward = 11.00
# Episode 425: Total Reward = 12.00
# Episode 426: Total Reward = 13.00
# Episode 427: Total Reward = 19.00
# Episode 428: Total Reward = 102.00
# Episode 429: Total Reward = 13.00
# Episode 430: Total Reward = 13.00
# Episode 431: Total Reward = 13.00
# Episode 432: Total Reward = 15.00
# Episode 433: Total Reward = 88.00
# Episode 434: Total Reward = 73.00
# Episode 435: Total Reward = 108.00
# Episode 436: Total Reward = 106.00
# Episode 437: Total Reward = 104.00
# Episode 438: Total Reward = 139.00
# Episode 439: Total Reward = 99.00
# Episode 440: Total Reward = 92.00
# Episode 441: Total Reward = 86.00
# Episode 442: Total Reward = 102.00
# Episode 443: Total Reward = 89.00
# Episode 444: Total Reward = 91.00
# Episode 445: Total Reward = 80.00
# Episode 446: Total Reward = 86.00
# Episode 447: Total Reward = 81.00
# Episode 448: Total Reward = 69.00
# Episode 449: Total Reward = 73.00
# Episode 450: Total Reward = 66.00
# Episode 451: Total Reward = 74.00
# Episode 452: Total Reward = 87.00
# Episode 453: Total Reward = 86.00
# Episode 454: Total Reward = 88.00
# Episode 455: Total Reward = 79.00
# Episode 456: Total Reward = 85.00
# Episode 457: Total Reward = 58.00
# Episode 458: Total Reward = 78.00
# Episode 459: Total Reward = 94.00
# Episode 460: Total Reward = 83.00
# Episode 461: Total Reward = 84.00
# Episode 462: Total Reward = 88.00
# Episode 463: Total Reward = 97.00
# Episode 464: Total Reward = 79.00
# Episode 465: Total Reward = 84.00
# Episode 466: Total Reward = 78.00
# Episode 467: Total Reward = 71.00
# Episode 468: Total Reward = 80.00
# Episode 469: Total Reward = 93.00
# Episode 470: Total Reward = 103.00
# Episode 471: Total Reward = 81.00
# Episode 472: Total Reward = 85.00
# Episode 473: Total Reward = 74.00
# Episode 474: Total Reward = 84.00
# Episode 475: Total Reward = 118.00
# Episode 476: Total Reward = 114.00
# Episode 477: Total Reward = 150.00
# Episode 478: Total Reward = 200.00
# Episode 479: Total Reward = 83.00
# Episode 480: Total Reward = 115.00
# Episode 481: Total Reward = 15.00
# Episode 482: Total Reward = 15.00
# Episode 483: Total Reward = 25.00
# Episode 484: Total Reward = 138.00
# Episode 485: Total Reward = 105.00
# Episode 486: Total Reward = 101.00
# Episode 487: Total Reward = 63.00
# Episode 488: Total Reward = 44.00
# Episode 489: Total Reward = 118.00
# Episode 490: Total Reward = 91.00
# Episode 491: Total Reward = 55.00
# Episode 492: Total Reward = 30.00
# Episode 493: Total Reward = 30.00
# Episode 494: Total Reward = 39.00
# Episode 495: Total Reward = 47.00
# Episode 496: Total Reward = 41.00
# Episode 497: Total Reward = 39.00
# Episode 498: Total Reward = 31.00
# Episode 499: Total Reward = 15.00
# Episode 500: Total Reward = 15.00
# Episode 501: Total Reward = 16.00
# Episode 502: Total Reward = 22.00
# Episode 503: Total Reward = 73.00
# Episode 504: Total Reward = 200.00
# Episode 505: Total Reward = 132.00
# Episode 506: Total Reward = 90.00
# Episode 507: Total Reward = 159.00
# Episode 508: Total Reward = 200.00
# Episode 509: Total Reward = 38.00
# Episode 510: Total Reward = 200.00
# Episode 511: Total Reward = 200.00
# Episode 512: Total Reward = 148.00
# Episode 513: Total Reward = 200.00
# Episode 514: Total Reward = 200.00
# Episode 515: Total Reward = 200.00
# Episode 516: Total Reward = 200.00
# Episode 517: Total Reward = 152.00
# Episode 518: Total Reward = 200.00
# Episode 519: Total Reward = 200.00
# Episode 520: Total Reward = 200.00
# Episode 521: Total Reward = 200.00
# Episode 522: Total Reward = 200.00
# Episode 523: Total Reward = 200.00
# Episode 524: Total Reward = 12.00
# Episode 525: Total Reward = 8.00
# Episode 526: Total Reward = 8.00
# Episode 527: Total Reward = 8.00
# Episode 528: Total Reward = 10.00
# Episode 529: Total Reward = 8.00
# Episode 530: Total Reward = 15.00
# Episode 531: Total Reward = 84.00
# Episode 532: Total Reward = 11.00
# Episode 533: Total Reward = 11.00
# Episode 534: Total Reward = 12.00
# Episode 535: Total Reward = 11.00
# Episode 536: Total Reward = 11.00
# Episode 537: Total Reward = 11.00
# Episode 538: Total Reward = 13.00
# Episode 539: Total Reward = 13.00
# Episode 540: Total Reward = 15.00
# Episode 541: Total Reward = 87.00
# Episode 542: Total Reward = 103.00
# Episode 543: Total Reward = 91.00
# Episode 544: Total Reward = 199.00
# Episode 545: Total Reward = 114.00
# Episode 546: Total Reward = 139.00
# Episode 547: Total Reward = 131.00
# Episode 548: Total Reward = 114.00
# Episode 549: Total Reward = 113.00
# Episode 550: Total Reward = 122.00
# Episode 551: Total Reward = 100.00
# Episode 552: Total Reward = 94.00
# Episode 553: Total Reward = 119.00
# Episode 554: Total Reward = 108.00
# Episode 555: Total Reward = 198.00
# Episode 556: Total Reward = 200.00
# Episode 557: Total Reward = 131.00
# Episode 558: Total Reward = 200.00
# Episode 559: Total Reward = 200.00
# Episode 560: Total Reward = 177.00
# Episode 561: Total Reward = 200.00
# Episode 562: Total Reward = 200.00
# Episode 563: Total Reward = 200.00
# Episode 564: Total Reward = 200.00
# Episode 565: Total Reward = 200.00
# Episode 566: Total Reward = 200.00
# Episode 567: Total Reward = 200.00
# Episode 568: Total Reward = 146.00
# Episode 569: Total Reward = 44.00
# Episode 570: Total Reward = 38.00
# Episode 571: Total Reward = 72.00
# Episode 572: Total Reward = 89.00
# Episode 573: Total Reward = 82.00
# Episode 574: Total Reward = 59.00
# Episode 575: Total Reward = 137.00
# Episode 576: Total Reward = 200.00
# Episode 577: Total Reward = 197.00
# Episode 578: Total Reward = 200.00
# Episode 579: Total Reward = 111.00
# Episode 580: Total Reward = 200.00
# Episode 581: Total Reward = 200.00
# Episode 582: Total Reward = 200.00
# Episode 583: Total Reward = 9.00
# Episode 584: Total Reward = 8.00
# Episode 585: Total Reward = 12.00
# Episode 586: Total Reward = 200.00
# Episode 587: Total Reward = 200.00
# Episode 588: Total Reward = 155.00
# Episode 589: Total Reward = 13.00
# Episode 590: Total Reward = 12.00
# Episode 591: Total Reward = 12.00
# Episode 592: Total Reward = 12.00
# Episode 593: Total Reward = 16.00
# Episode 594: Total Reward = 200.00
# Episode 595: Total Reward = 151.00
# Episode 596: Total Reward = 10.00
# Episode 597: Total Reward = 8.00
# Episode 598: Total Reward = 8.00
# Episode 599: Total Reward = 8.00
# Episode 600: Total Reward = 8.00
# Episode 601: Total Reward = 9.00
# Episode 602: Total Reward = 9.00
# Episode 603: Total Reward = 9.00
# Episode 604: Total Reward = 9.00
# Episode 605: Total Reward = 9.00
# Episode 606: Total Reward = 11.00
# Episode 607: Total Reward = 200.00
# Episode 608: Total Reward = 85.00
# Episode 609: Total Reward = 14.00
# Episode 610: Total Reward = 11.00
# Episode 611: Total Reward = 13.00
# Episode 612: Total Reward = 21.00
# Episode 613: Total Reward = 126.00
# Episode 614: Total Reward = 200.00
# Episode 615: Total Reward = 187.00
# Episode 616: Total Reward = 164.00
# Episode 617: Total Reward = 166.00
# Episode 618: Total Reward = 200.00
# Episode 619: Total Reward = 193.00
# Episode 620: Total Reward = 159.00
# Episode 621: Total Reward = 170.00
# Episode 622: Total Reward = 143.00
# Episode 623: Total Reward = 133.00
# Episode 624: Total Reward = 191.00
# Episode 625: Total Reward = 200.00
# Episode 626: Total Reward = 172.00
# Episode 627: Total Reward = 200.00
# Episode 628: Total Reward = 200.00
# Episode 629: Total Reward = 16.00
# Episode 630: Total Reward = 151.00
# Episode 631: Total Reward = 200.00
# Episode 632: Total Reward = 200.00
# Episode 633: Total Reward = 200.00
# Episode 634: Total Reward = 200.00
# Episode 635: Total Reward = 200.00
# Episode 636: Total Reward = 136.00
# Episode 637: Total Reward = 16.00
# Episode 638: Total Reward = 108.00
# Episode 639: Total Reward = 137.00
# Episode 640: Total Reward = 200.00
# Episode 641: Total Reward = 198.00
# Episode 642: Total Reward = 186.00
# Episode 643: Total Reward = 200.00
# Episode 644: Total Reward = 15.00
# Episode 645: Total Reward = 15.00
# Episode 646: Total Reward = 15.00
# Episode 647: Total Reward = 17.00
# Episode 648: Total Reward = 200.00
# Episode 649: Total Reward = 107.00
# Episode 650: Total Reward = 8.00
# Episode 651: Total Reward = 8.00
# Episode 652: Total Reward = 8.00
# Episode 653: Total Reward = 11.00
# Episode 654: Total Reward = 8.00
# Episode 655: Total Reward = 8.00
# Episode 656: Total Reward = 8.00
# Episode 657: Total Reward = 8.00
# Episode 658: Total Reward = 8.00
# Episode 659: Total Reward = 8.00
# Episode 660: Total Reward = 8.00
# Episode 661: Total Reward = 8.00
# Episode 662: Total Reward = 8.00
# Episode 663: Total Reward = 10.00
# Episode 664: Total Reward = 200.00
# Episode 665: Total Reward = 167.00
# Episode 666: Total Reward = 15.00
# Episode 667: Total Reward = 16.00
# Episode 668: Total Reward = 179.00
# Episode 669: Total Reward = 200.00
# Episode 670: Total Reward = 200.00
# Episode 671: Total Reward = 165.00
# Episode 672: Total Reward = 200.00
# Episode 673: Total Reward = 175.00
# Episode 674: Total Reward = 175.00
# Episode 675: Total Reward = 200.00
# Episode 676: Total Reward = 200.00
# Episode 677: Total Reward = 192.00
# Episode 678: Total Reward = 200.00
# Episode 679: Total Reward = 163.00
# Episode 680: Total Reward = 200.00
# Episode 681: Total Reward = 188.00
# Episode 682: Total Reward = 198.00
# Episode 683: Total Reward = 9.00
# Episode 684: Total Reward = 8.00
# Episode 685: Total Reward = 8.00
# Episode 686: Total Reward = 8.00
# Episode 687: Total Reward = 10.00
# Episode 688: Total Reward = 8.00
# Episode 689: Total Reward = 9.00
# Episode 690: Total Reward = 8.00
# Episode 691: Total Reward = 8.00
# Episode 692: Total Reward = 8.00
# Episode 693: Total Reward = 8.00
# Episode 694: Total Reward = 11.00
# Episode 695: Total Reward = 8.00
# Episode 696: Total Reward = 8.00
# Episode 697: Total Reward = 8.00
# Episode 698: Total Reward = 8.00
# Episode 699: Total Reward = 8.00
# Episode 700: Total Reward = 8.00
# Episode 701: Total Reward = 9.00
# Episode 702: Total Reward = 156.00
# Episode 703: Total Reward = 86.00
# Episode 704: Total Reward = 105.00
# Episode 705: Total Reward = 26.00
# Episode 706: Total Reward = 181.00
# Episode 707: Total Reward = 200.00
# Episode 708: Total Reward = 184.00
# Episode 709: Total Reward = 200.00
# Episode 710: Total Reward = 197.00
# Episode 711: Total Reward = 17.00
# Episode 712: Total Reward = 19.00
# Episode 713: Total Reward = 18.00
# Episode 714: Total Reward = 155.00
# Episode 715: Total Reward = 200.00
# Episode 716: Total Reward = 187.00
# Episode 717: Total Reward = 200.00
# Episode 718: Total Reward = 200.00
# Episode 719: Total Reward = 200.00
# Episode 720: Total Reward = 183.00
# Episode 721: Total Reward = 200.00
# Episode 722: Total Reward = 115.00
# Episode 723: Total Reward = 155.00
# Episode 724: Total Reward = 148.00
# Episode 725: Total Reward = 200.00
# Episode 726: Total Reward = 130.00
# Episode 727: Total Reward = 200.00
# Episode 728: Total Reward = 200.00
# Episode 729: Total Reward = 200.00
# Episode 730: Total Reward = 200.00
# Episode 731: Total Reward = 200.00
# Episode 732: Total Reward = 200.00
# Episode 733: Total Reward = 182.00
# Episode 734: Total Reward = 200.00
# Episode 735: Total Reward = 200.00
# Episode 736: Total Reward = 200.00
# Episode 737: Total Reward = 200.00
# Episode 738: Total Reward = 200.00
# Episode 739: Total Reward = 75.00
# Episode 740: Total Reward = 13.00
# Episode 741: Total Reward = 11.00
# Episode 742: Total Reward = 11.00
# Episode 743: Total Reward = 12.00
# Episode 744: Total Reward = 11.00
# Episode 745: Total Reward = 13.00
# Episode 746: Total Reward = 200.00
# Episode 747: Total Reward = 172.00
# Episode 748: Total Reward = 8.00
# Episode 749: Total Reward = 10.00
# Episode 750: Total Reward = 8.00
# Episode 751: Total Reward = 8.00
# Episode 752: Total Reward = 8.00
# Episode 753: Total Reward = 9.00
# Episode 754: Total Reward = 11.00
# Episode 755: Total Reward = 200.00
# Episode 756: Total Reward = 200.00
# Episode 757: Total Reward = 156.00
# Episode 758: Total Reward = 200.00
# Episode 759: Total Reward = 200.00
# Episode 760: Total Reward = 200.00
# Episode 761: Total Reward = 197.00
# Episode 762: Total Reward = 200.00
# Episode 763: Total Reward = 200.00
# Episode 764: Total Reward = 200.00
# Episode 765: Total Reward = 200.00
# Episode 766: Total Reward = 178.00
# Episode 767: Total Reward = 8.00
# Episode 768: Total Reward = 8.00
# Episode 769: Total Reward = 11.00
# Episode 770: Total Reward = 8.00
# Episode 771: Total Reward = 8.00
# Episode 772: Total Reward = 8.00
# Episode 773: Total Reward = 200.00
# Episode 774: Total Reward = 200.00
# Episode 775: Total Reward = 198.00
# Episode 776: Total Reward = 11.00
# Episode 777: Total Reward = 11.00
# Episode 778: Total Reward = 11.00
# Episode 779: Total Reward = 11.00
# Episode 780: Total Reward = 12.00
# Episode 781: Total Reward = 195.00
# Episode 782: Total Reward = 200.00
# Episode 783: Total Reward = 184.00
# Episode 784: Total Reward = 179.00
# Episode 785: Total Reward = 200.00
# Episode 786: Total Reward = 200.00
# Episode 787: Total Reward = 200.00
# Episode 788: Total Reward = 198.00
# Episode 789: Total Reward = 200.00
# Episode 790: Total Reward = 200.00
# Episode 791: Total Reward = 200.00
# Episode 792: Total Reward = 200.00
# Episode 793: Total Reward = 200.00
# Episode 794: Total Reward = 146.00
# Episode 795: Total Reward = 13.00
# Episode 796: Total Reward = 12.00
# Episode 797: Total Reward = 11.00
# Episode 798: Total Reward = 12.00
# Episode 799: Total Reward = 17.00
# Episode 800: Total Reward = 200.00
# Episode 801: Total Reward = 180.00
# Episode 802: Total Reward = 8.00
# Episode 803: Total Reward = 8.00
# Episode 804: Total Reward = 8.00
# Episode 805: Total Reward = 8.00
# Episode 806: Total Reward = 8.00
# Episode 807: Total Reward = 12.00
# Episode 808: Total Reward = 9.00
# Episode 809: Total Reward = 9.00
# Episode 810: Total Reward = 200.00
# Episode 811: Total Reward = 200.00
# Episode 812: Total Reward = 200.00
# Episode 813: Total Reward = 200.00
# Episode 814: Total Reward = 17.00
# Episode 815: Total Reward = 19.00
# Episode 816: Total Reward = 147.00
# Episode 817: Total Reward = 183.00
# Episode 818: Total Reward = 200.00
# Episode 819: Total Reward = 177.00
# Episode 820: Total Reward = 200.00
# Episode 821: Total Reward = 200.00
# Episode 822: Total Reward = 200.00
# Episode 823: Total Reward = 200.00
# Episode 824: Total Reward = 200.00
# Episode 825: Total Reward = 200.00
# Episode 826: Total Reward = 123.00
# Episode 827: Total Reward = 137.00
# Episode 828: Total Reward = 200.00
# Episode 829: Total Reward = 158.00
# Episode 830: Total Reward = 176.00
# Episode 831: Total Reward = 200.00
# Episode 832: Total Reward = 200.00
# Episode 833: Total Reward = 195.00
# Episode 834: Total Reward = 200.00
# Episode 835: Total Reward = 200.00
# Episode 836: Total Reward = 109.00
# Episode 837: Total Reward = 13.00
# Episode 838: Total Reward = 14.00
# Episode 839: Total Reward = 13.00
# Episode 840: Total Reward = 13.00
# Episode 841: Total Reward = 200.00
# Episode 842: Total Reward = 200.00
# Episode 843: Total Reward = 193.00
# Episode 844: Total Reward = 174.00
# Episode 845: Total Reward = 200.00
# Episode 846: Total Reward = 200.00
# Episode 847: Total Reward = 200.00
# Episode 848: Total Reward = 200.00
# Episode 849: Total Reward = 200.00
# Episode 850: Total Reward = 200.00
# Episode 851: Total Reward = 200.00
# Episode 852: Total Reward = 200.00
# Episode 853: Total Reward = 200.00
# Episode 854: Total Reward = 17.00
# Episode 855: Total Reward = 14.00
# Episode 856: Total Reward = 200.00
# Episode 857: Total Reward = 200.00
# Episode 858: Total Reward = 200.00
# Episode 859: Total Reward = 200.00
# Episode 860: Total Reward = 200.00
# Episode 861: Total Reward = 200.00
# Episode 862: Total Reward = 200.00
# Episode 863: Total Reward = 200.00
# Episode 864: Total Reward = 200.00
# Episode 865: Total Reward = 200.00
# Episode 866: Total Reward = 200.00
# Episode 867: Total Reward = 185.00
# Episode 868: Total Reward = 8.00
# Episode 869: Total Reward = 144.00
# Episode 870: Total Reward = 15.00
# Episode 871: Total Reward = 200.00
# Episode 872: Total Reward = 200.00
# Episode 873: Total Reward = 200.00
# Episode 874: Total Reward = 200.00
# Episode 875: Total Reward = 200.00
# Episode 876: Total Reward = 200.00
# Episode 877: Total Reward = 200.00
# Episode 878: Total Reward = 200.00
# Episode 879: Total Reward = 200.00
# Episode 880: Total Reward = 200.00
# Episode 881: Total Reward = 200.00
# Episode 882: Total Reward = 200.00
# Episode 883: Total Reward = 13.00
# Episode 884: Total Reward = 11.00
# Episode 885: Total Reward = 13.00
# Episode 886: Total Reward = 200.00
# Episode 887: Total Reward = 200.00
# Episode 888: Total Reward = 200.00
# Episode 889: Total Reward = 200.00
# Episode 890: Total Reward = 200.00
# Episode 891: Total Reward = 200.00
# Episode 892: Total Reward = 200.00
# Episode 893: Total Reward = 200.00
# Episode 894: Total Reward = 200.00
# Episode 895: Total Reward = 200.00
# Episode 896: Total Reward = 174.00
# Episode 897: Total Reward = 170.00
# Episode 898: Total Reward = 153.00
# Episode 899: Total Reward = 200.00
# Episode 900: Total Reward = 12.00
# Episode 901: Total Reward = 9.00
# Episode 902: Total Reward = 9.00
# Episode 903: Total Reward = 9.00
# Episode 904: Total Reward = 9.00
# Episode 905: Total Reward = 9.00
# Episode 906: Total Reward = 9.00
# Episode 907: Total Reward = 12.00
# Episode 908: Total Reward = 200.00
# Episode 909: Total Reward = 192.00
# Episode 910: Total Reward = 184.00
# Episode 911: Total Reward = 14.00
# Episode 912: Total Reward = 16.00
# Episode 913: Total Reward = 200.00
# Episode 914: Total Reward = 198.00
# Episode 915: Total Reward = 200.00
# Episode 916: Total Reward = 200.00
# Episode 917: Total Reward = 200.00
# Episode 918: Total Reward = 200.00
# Episode 919: Total Reward = 166.00
# Episode 920: Total Reward = 14.00
# Episode 921: Total Reward = 14.00
# Episode 922: Total Reward = 17.00
# Episode 923: Total Reward = 169.00
# Episode 924: Total Reward = 200.00
# Episode 925: Total Reward = 200.00
# Episode 926: Total Reward = 200.00
# Episode 927: Total Reward = 200.00
# Episode 928: Total Reward = 200.00
# Episode 929: Total Reward = 200.00
# Episode 930: Total Reward = 200.00
# Episode 931: Total Reward = 194.00
# Episode 932: Total Reward = 169.00
# Episode 933: Total Reward = 153.00
# Episode 934: Total Reward = 199.00
# Episode 935: Total Reward = 128.00
# Episode 936: Total Reward = 147.00
# Episode 937: Total Reward = 177.00
# Episode 938: Total Reward = 137.00
# Episode 939: Total Reward = 135.00
# Episode 940: Total Reward = 141.00
# Episode 941: Total Reward = 160.00
# Episode 942: Total Reward = 160.00
# Episode 943: Total Reward = 124.00
# Episode 944: Total Reward = 106.00
# Episode 945: Total Reward = 117.00
# Episode 946: Total Reward = 115.00
# Episode 947: Total Reward = 112.00
# Episode 948: Total Reward = 129.00
# Episode 949: Total Reward = 135.00
# Episode 950: Total Reward = 166.00
# Episode 951: Total Reward = 111.00
# Episode 952: Total Reward = 117.00
# Episode 953: Total Reward = 111.00
# Episode 954: Total Reward = 124.00
# Episode 955: Total Reward = 200.00
# Episode 956: Total Reward = 135.00
# Episode 957: Total Reward = 9.00
# Episode 958: Total Reward = 9.00
# Episode 959: Total Reward = 8.00
# Episode 960: Total Reward = 8.00
# Episode 961: Total Reward = 10.00
# Episode 962: Total Reward = 8.00
# Episode 963: Total Reward = 8.00
# Episode 964: Total Reward = 10.00
# Episode 965: Total Reward = 9.00
# Episode 966: Total Reward = 9.00
# Episode 967: Total Reward = 9.00
# Episode 968: Total Reward = 175.00
# Episode 969: Total Reward = 19.00
# Episode 970: Total Reward = 92.00
# Episode 971: Total Reward = 15.00
# Episode 972: Total Reward = 13.00
# Episode 973: Total Reward = 12.00
# Episode 974: Total Reward = 12.00
# Episode 975: Total Reward = 13.00
# Episode 976: Total Reward = 129.00
# Episode 977: Total Reward = 171.00
# Episode 978: Total Reward = 166.00
# Episode 979: Total Reward = 200.00
# Episode 980: Total Reward = 140.00
# Episode 981: Total Reward = 181.00
# Episode 982: Total Reward = 200.00
# Episode 983: Total Reward = 145.00
# Episode 984: Total Reward = 124.00
# Episode 985: Total Reward = 137.00
# Episode 986: Total Reward = 161.00
# Episode 987: Total Reward = 200.00
# Episode 988: Total Reward = 191.00
# Episode 989: Total Reward = 141.00
# Episode 990: Total Reward = 200.00
# Episode 991: Total Reward = 200.00
# Episode 992: Total Reward = 195.00
# Episode 993: Total Reward = 137.00
# Episode 994: Total Reward = 186.00
# Episode 995: Total Reward = 180.00
# Episode 996: Total Reward = 120.00
# Episode 997: Total Reward = 8.00
# Episode 998: Total Reward = 8.00
# Episode 999: Total Reward = 10.00
