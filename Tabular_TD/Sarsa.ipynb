# %%
import numpy as np
import gymnasium as gym
import Toy_Envs.gridworld as gw
import time

# %% [markdown]
# The core idea of Sarsa (i.e., Step-1 TD Algorithm) is to solve the **Bellman equation** (action value ver.) by using stochastic approximation, so that policy evaluation can be done.
#
# \begin{equation}
# \begin{aligned}
# q_{t+1}\left(s_t, a_t\right) & =q_t\left(s_t, a_t\right)-\alpha_t\left(s_t, a_t\right)\left[q_t\left(s_t, a_t\right)-\left[r_{t+1}+\gamma q_t\left(s_{t+1}, a_{t+1}\right)\right]\right] \\
# q_{t+1}(s, a) & =q_t(s, a), \quad \text { for all }(s, a) \neq\left(s_t, a_t\right)
# \end{aligned}
# \end{equation}
#
# As q is updated, the policy is also updated by using the $\epsilon$-greedy policy.
#
# \begin{equation}
# \begin{aligned}
# & \pi_{t+1}\left(a \mid s_t\right)=1-\frac{\epsilon}{|\mathcal{A}(s)|}(|\mathcal{A}(s)|-1) \text { if } a=\arg \max _a q_{t+1}\left(s_t, a\right) \\
# & \pi_{t+1}\left(a \mid s_t\right)=\frac{\epsilon}{|\mathcal{A}(s)|} \text { otherwise }
# \end{aligned}
# \end{equation}

# %%
class Sarsa_Agent():
    """ Since the discrete actions have been redefined as {0,1,2,3} by using the wapper file, we can simply represent the action by a number. """
    
    def __init__(self,
                 obs_dim:int,
                 action_dim:int,
                 epsilon:float = 0.1,
                 lr:float = 0.1,
                 gamma:float = 0.9) -> None:
        
        self.obs_dim = obs_dim
        self.action_dim = action_dim
        self.Q = np.zeros((self.obs_dim,self.action_dim))
        
        self.epsilon = epsilon
        self.lr = lr
        self.gamma = gamma

    def get_greedy_action(self,obs:int) -> int:
        # action of determine policy by policy improvement
        Q_list = self.Q[obs,:]
        # action = np.argmax(Q_list) # for this method, [0,0,0,0] will always choose action[0]
        action = np.random.choice(np.flatnonzero(Q_list==Q_list.max()))  # for this method, [0,0,0,0] will choose action[0,1,2,3] randomly
        return action

    def get_action(self,obs:int) -> int:
        # epsilon-greedy policy
        if np.random.uniform(0,1) < self.epsilon:
            action = np.random.choice(self.action_dim)
        else:
            # use improved policy
            action = self.get_greedy_action(obs)
            
        return action
    
    def policy_evaluation(self,
                          obs:int,
                          action:int,
                          reward:float,
                          next_obs:int,
                          next_action:int,
                          done:bool) -> None:
        current_Q = self.Q[obs,action]
        # Note that if terminated is True, there will be no next_state and next_action. In this case, the target_Q is just reward
        TD_target = reward + (1-float(done)) * self.gamma * self.Q[next_obs,next_action]
        self.Q[obs,action] -= self.lr * (current_Q - TD_target)

# %%
class TrainManager():
    
    def __init__(self,
                 env:gym.Env,
                 episode_num:int = 1000,
                 lr:float = 0.1,
                 gamma:float = 0.9,
                 epsilon:float = 0.1) -> None:  
        
        self.env = env
        self.episode_num = episode_num
        obs_dim = env.observation_space.n
        action_dim = env.action_space.n
        self.agent = Sarsa_Agent(
                    obs_dim = obs_dim, 
                    action_dim = action_dim,
                    epsilon = epsilon,
                    lr = lr, 
                    gamma = gamma 
                )
    
    def train_episode(self,is_render:bool=False) -> float:
        total_reward = 0 # record total reward in one episode
        obs,_ = self.env.reset() # reset env and get initial state
        while True:
            action = self.agent.get_action(obs) # get action using learned epsilon-greedy policy
            next_obs, reward, terminated, truncated, _ = self.env.step(action) # take action and get next_state, reward, done, info
            """In Gymnasium or Gym v0.26, done is True when terminated or truncated. 
                In Gym early version, there is done but not terminated, truncated here.
                You should modify the code according to the version of Gym you use."""
            done = terminated or truncated
            total_reward += reward
            # For Sarsa, we NEED obtain a' using the current policy        
            next_action = self.agent.get_action(next_obs)
            # using data to do policy evaluation
            self.agent.policy_evaluation(obs,action,reward,next_obs,next_action,done)
            # update state and action
            obs = next_obs     
            if is_render:
                self.env.render() # !! You can find the game window in the taskbar !!
                time.sleep(0.1) # set a speed for visualization
                
            if done:
                break
            
        return total_reward       

    def test_episode(self) -> float:
        total_reward = 0 # record total reward in one episode
        obs,_ = self.env.reset() # reset env and get initial state
        while True:
            action = self.agent.get_greedy_action(obs) # get action using learned greedy policy
            next_obs, reward, terminated, truncated, _= self.env.step(action) # take action and get next_state, reward, done, info
            done = terminated or truncated
            obs = next_obs
            total_reward += reward
            self.env.render()
            time.sleep(0.1)
            if done:
                break
            
        return total_reward
            
    def train(self) -> None:       
        is_render = False
        for e in range(self.episode_num):
            episode_reward = self.train_episode(is_render)
            print('Episode %s: Total Reward = %.2f'%(e,episode_reward)) 
            
            if e%50==0:
                is_render = True
            else:
                is_render = False
                
        test_reward = self.test_episode()
        print('Test Total Reward = %.2f'%(test_reward))

# %%
if __name__ == "__main__":
    env = gym.make('CliffWalking-v0')
    env = gw.CliffWalkingWapper(env)
    
    """Here is another game you can try."""
    
    # env = gym.make("FrozenLake-v1", is_slippery=False)
    # env = gw.FrozenLakeWapper(env)
    
    Manger = TrainManager(env=env,
                        episode_num=500,
                        lr=0.1,
                        gamma=0.9,
                        epsilon=0.1
                        )
    Manger.train()
# Out:
# Episode 0: Total Reward = -2313.00
# Episode 1: Total Reward = -179.00
# Episode 2: Total Reward = -329.00
# Episode 3: Total Reward = -291.00
# Episode 4: Total Reward = -193.00
# Episode 5: Total Reward = -293.00
# Episode 6: Total Reward = -483.00
# Episode 7: Total Reward = -380.00
# Episode 8: Total Reward = -69.00
# Episode 9: Total Reward = -350.00
# Episode 10: Total Reward = -132.00
# Episode 11: Total Reward = -253.00
# Episode 12: Total Reward = -95.00
# Episode 13: Total Reward = -89.00
# Episode 14: Total Reward = -271.00
# Episode 15: Total Reward = -60.00
# Episode 16: Total Reward = -57.00
# Episode 17: Total Reward = -294.00
# Episode 18: Total Reward = -183.00
# Episode 19: Total Reward = -101.00
# Episode 20: Total Reward = -50.00
# Episode 21: Total Reward = -176.00
# Episode 22: Total Reward = -69.00
# Episode 23: Total Reward = -99.00
# Episode 24: Total Reward = -222.00
# Episode 25: Total Reward = -86.00
# Episode 26: Total Reward = -65.00
# Episode 27: Total Reward = -75.00
# Episode 28: Total Reward = -128.00
# Episode 29: Total Reward = -195.00
# Episode 30: Total Reward = -53.00
# Episode 31: Total Reward = -71.00
# Episode 32: Total Reward = -93.00
# Episode 33: Total Reward = -92.00
# Episode 34: Total Reward = -420.00
# Episode 35: Total Reward = -78.00
# Episode 36: Total Reward = -71.00
# Episode 37: Total Reward = -108.00
# Episode 38: Total Reward = -44.00
# Episode 39: Total Reward = -374.00
# Episode 40: Total Reward = -67.00
# Episode 41: Total Reward = -31.00
# Episode 42: Total Reward = -82.00
# Episode 43: Total Reward = -220.00
# Episode 44: Total Reward = -44.00
# Episode 45: Total Reward = -51.00
# Episode 46: Total Reward = -52.00
# Episode 47: Total Reward = -85.00
# Episode 48: Total Reward = -51.00
# Episode 49: Total Reward = -73.00
# Episode 50: Total Reward = -202.00
# Episode 51: Total Reward = -57.00
# Episode 52: Total Reward = -29.00
# Episode 53: Total Reward = -152.00
# Episode 54: Total Reward = -56.00
# Episode 55: Total Reward = -45.00
# Episode 56: Total Reward = -43.00
# Episode 57: Total Reward = -183.00
# Episode 58: Total Reward = -300.00
# Episode 59: Total Reward = -47.00
# Episode 60: Total Reward = -34.00
# Episode 61: Total Reward = -53.00
# Episode 62: Total Reward = -59.00
# Episode 63: Total Reward = -37.00
# Episode 64: Total Reward = -29.00
# Episode 65: Total Reward = -45.00
# Episode 66: Total Reward = -35.00
# Episode 67: Total Reward = -30.00
# Episode 68: Total Reward = -55.00
# Episode 69: Total Reward = -49.00
# Episode 70: Total Reward = -43.00
# Episode 71: Total Reward = -27.00
# Episode 72: Total Reward = -47.00
# Episode 73: Total Reward = -50.00
# Episode 74: Total Reward = -25.00
# Episode 75: Total Reward = -244.00
# Episode 76: Total Reward = -40.00
# Episode 77: Total Reward = -224.00
# Episode 78: Total Reward = -34.00
# Episode 79: Total Reward = -41.00
# Episode 80: Total Reward = -46.00
# Episode 81: Total Reward = -54.00
# Episode 82: Total Reward = -21.00
# Episode 83: Total Reward = -22.00
# Episode 84: Total Reward = -47.00
# Episode 85: Total Reward = -62.00
# Episode 86: Total Reward = -37.00
# Episode 87: Total Reward = -46.00
# Episode 88: Total Reward = -41.00
# Episode 89: Total Reward = -41.00
# Episode 90: Total Reward = -36.00
# Episode 91: Total Reward = -40.00
# Episode 92: Total Reward = -54.00
# Episode 93: Total Reward = -33.00
# Episode 94: Total Reward = -41.00
# Episode 95: Total Reward = -31.00
# Episode 96: Total Reward = -47.00
# Episode 97: Total Reward = -33.00
# Episode 98: Total Reward = -34.00
# Episode 99: Total Reward = -27.00
# Episode 100: Total Reward = -42.00
# Episode 101: Total Reward = -44.00
# Episode 102: Total Reward = -33.00
# Episode 103: Total Reward = -30.00
# Episode 104: Total Reward = -35.00
# Episode 105: Total Reward = -33.00
# Episode 106: Total Reward = -25.00
# Episode 107: Total Reward = -160.00
# Episode 108: Total Reward = -34.00
# Episode 109: Total Reward = -24.00
# Episode 110: Total Reward = -154.00
# Episode 111: Total Reward = -23.00
# Episode 112: Total Reward = -28.00
# Episode 113: Total Reward = -24.00
# Episode 114: Total Reward = -51.00
# Episode 115: Total Reward = -47.00
# Episode 116: Total Reward = -35.00
# Episode 117: Total Reward = -38.00
# Episode 118: Total Reward = -26.00
# Episode 119: Total Reward = -31.00
# Episode 120: Total Reward = -32.00
# Episode 121: Total Reward = -34.00
# Episode 122: Total Reward = -29.00
# Episode 123: Total Reward = -26.00
# Episode 124: Total Reward = -25.00
# Episode 125: Total Reward = -28.00
# Episode 126: Total Reward = -154.00
# Episode 127: Total Reward = -32.00
# Episode 128: Total Reward = -32.00
# Episode 129: Total Reward = -35.00
# Episode 130: Total Reward = -143.00
# Episode 131: Total Reward = -24.00
# Episode 132: Total Reward = -36.00
# Episode 133: Total Reward = -143.00
# Episode 134: Total Reward = -35.00
# Episode 135: Total Reward = -41.00
# Episode 136: Total Reward = -28.00
# Episode 137: Total Reward = -24.00
# Episode 138: Total Reward = -23.00
# Episode 139: Total Reward = -49.00
# Episode 140: Total Reward = -26.00
# Episode 141: Total Reward = -28.00
# Episode 142: Total Reward = -43.00
# Episode 143: Total Reward = -30.00
# Episode 144: Total Reward = -31.00
# Episode 145: Total Reward = -30.00
# Episode 146: Total Reward = -22.00
# Episode 147: Total Reward = -36.00
# Episode 148: Total Reward = -137.00
# Episode 149: Total Reward = -23.00
# Episode 150: Total Reward = -150.00
# Episode 151: Total Reward = -23.00
# Episode 152: Total Reward = -48.00
# Episode 153: Total Reward = -39.00
# Episode 154: Total Reward = -32.00
# Episode 155: Total Reward = -24.00
# Episode 156: Total Reward = -25.00
# Episode 157: Total Reward = -35.00
# Episode 158: Total Reward = -28.00
# Episode 159: Total Reward = -31.00
# Episode 160: Total Reward = -33.00
# Episode 161: Total Reward = -36.00
# Episode 162: Total Reward = -25.00
# Episode 163: Total Reward = -21.00
# Episode 164: Total Reward = -29.00
# Episode 165: Total Reward = -25.00
# Episode 166: Total Reward = -36.00
# Episode 167: Total Reward = -29.00
# Episode 168: Total Reward = -122.00
# Episode 169: Total Reward = -29.00
# Episode 170: Total Reward = -24.00
# Episode 171: Total Reward = -28.00
# Episode 172: Total Reward = -27.00
# Episode 173: Total Reward = -24.00
# Episode 174: Total Reward = -30.00
# Episode 175: Total Reward = -34.00
# Episode 176: Total Reward = -125.00
# Episode 177: Total Reward = -32.00
# Episode 178: Total Reward = -26.00
# Episode 179: Total Reward = -31.00
# Episode 180: Total Reward = -27.00
# Episode 181: Total Reward = -17.00
# Episode 182: Total Reward = -35.00
# Episode 183: Total Reward = -28.00
# Episode 184: Total Reward = -32.00
# Episode 185: Total Reward = -25.00
# Episode 186: Total Reward = -20.00
# Episode 187: Total Reward = -132.00
# Episode 188: Total Reward = -119.00
# Episode 189: Total Reward = -29.00
# Episode 190: Total Reward = -19.00
# Episode 191: Total Reward = -26.00
# Episode 192: Total Reward = -21.00
# Episode 193: Total Reward = -21.00
# Episode 194: Total Reward = -23.00
# Episode 195: Total Reward = -17.00
# Episode 196: Total Reward = -21.00
# Episode 197: Total Reward = -31.00
# Episode 198: Total Reward = -28.00
# Episode 199: Total Reward = -26.00
# Episode 200: Total Reward = -27.00
# Episode 201: Total Reward = -32.00
# Episode 202: Total Reward = -33.00
# Episode 203: Total Reward = -136.00
# Episode 204: Total Reward = -24.00
# Episode 205: Total Reward = -23.00
# Episode 206: Total Reward = -27.00
# Episode 207: Total Reward = -19.00
# Episode 208: Total Reward = -17.00
# Episode 209: Total Reward = -22.00
# Episode 210: Total Reward = -30.00
# Episode 211: Total Reward = -32.00
# Episode 212: Total Reward = -30.00
# Episode 213: Total Reward = -24.00
# Episode 214: Total Reward = -20.00
# Episode 215: Total Reward = -22.00
# Episode 216: Total Reward = -21.00
# Episode 217: Total Reward = -24.00
# Episode 218: Total Reward = -21.00
# Episode 219: Total Reward = -22.00
# Episode 220: Total Reward = -35.00
# Episode 221: Total Reward = -33.00
# Episode 222: Total Reward = -21.00
# Episode 223: Total Reward = -145.00
# Episode 224: Total Reward = -27.00
# Episode 225: Total Reward = -41.00
# Episode 226: Total Reward = -23.00
# Episode 227: Total Reward = -24.00
# Episode 228: Total Reward = -46.00
# Episode 229: Total Reward = -138.00
# Episode 230: Total Reward = -27.00
# Episode 231: Total Reward = -36.00
# Episode 232: Total Reward = -21.00
# Episode 233: Total Reward = -20.00
# Episode 234: Total Reward = -25.00
# Episode 235: Total Reward = -26.00
# Episode 236: Total Reward = -20.00
# Episode 237: Total Reward = -23.00
# Episode 238: Total Reward = -29.00
# Episode 239: Total Reward = -20.00
# Episode 240: Total Reward = -27.00
# Episode 241: Total Reward = -23.00
# Episode 242: Total Reward = -18.00
# Episode 243: Total Reward = -22.00
# Episode 244: Total Reward = -25.00
# Episode 245: Total Reward = -31.00
# Episode 246: Total Reward = -239.00
# Episode 247: Total Reward = -19.00
# Episode 248: Total Reward = -28.00
# Episode 249: Total Reward = -27.00
# Episode 250: Total Reward = -128.00
# Episode 251: Total Reward = -21.00
# Episode 252: Total Reward = -22.00
# Episode 253: Total Reward = -25.00
# Episode 254: Total Reward = -19.00
# Episode 255: Total Reward = -20.00
# Episode 256: Total Reward = -25.00
# Episode 257: Total Reward = -22.00
# Episode 258: Total Reward = -40.00
# Episode 259: Total Reward = -22.00
# Episode 260: Total Reward = -142.00
# Episode 261: Total Reward = -24.00
# Episode 262: Total Reward = -29.00
# Episode 263: Total Reward = -20.00
# Episode 264: Total Reward = -23.00
# Episode 265: Total Reward = -21.00
# Episode 266: Total Reward = -20.00
# Episode 267: Total Reward = -21.00
# Episode 268: Total Reward = -22.00
# Episode 269: Total Reward = -23.00
# Episode 270: Total Reward = -21.00
# Episode 271: Total Reward = -21.00
# Episode 272: Total Reward = -23.00
# Episode 273: Total Reward = -29.00
# Episode 274: Total Reward = -22.00
# Episode 275: Total Reward = -20.00
# Episode 276: Total Reward = -24.00
# Episode 277: Total Reward = -20.00
# Episode 278: Total Reward = -27.00
# Episode 279: Total Reward = -23.00
# Episode 280: Total Reward = -19.00
# Episode 281: Total Reward = -25.00
# Episode 282: Total Reward = -17.00
# Episode 283: Total Reward = -21.00
# Episode 284: Total Reward = -18.00
# Episode 285: Total Reward = -25.00
# Episode 286: Total Reward = -21.00
# Episode 287: Total Reward = -18.00
# Episode 288: Total Reward = -23.00
# Episode 289: Total Reward = -26.00
# Episode 290: Total Reward = -17.00
# Episode 291: Total Reward = -24.00
# Episode 292: Total Reward = -17.00
# Episode 293: Total Reward = -18.00
# Episode 294: Total Reward = -21.00
# Episode 295: Total Reward = -24.00
# Episode 296: Total Reward = -19.00
# Episode 297: Total Reward = -19.00
# Episode 298: Total Reward = -17.00
# Episode 299: Total Reward = -28.00
# Episode 300: Total Reward = -19.00
# Episode 301: Total Reward = -20.00
# Episode 302: Total Reward = -18.00
# Episode 303: Total Reward = -17.00
# Episode 304: Total Reward = -21.00
# Episode 305: Total Reward = -21.00
# Episode 306: Total Reward = -19.00
# Episode 307: Total Reward = -20.00
# Episode 308: Total Reward = -21.00
# Episode 309: Total Reward = -18.00
# Episode 310: Total Reward = -19.00
# Episode 311: Total Reward = -22.00
# Episode 312: Total Reward = -23.00
# Episode 313: Total Reward = -27.00
# Episode 314: Total Reward = -26.00
# Episode 315: Total Reward = -17.00
# Episode 316: Total Reward = -28.00
# Episode 317: Total Reward = -21.00
# Episode 318: Total Reward = -19.00
# Episode 319: Total Reward = -24.00
# Episode 320: Total Reward = -17.00
# Episode 321: Total Reward = -20.00
# Episode 322: Total Reward = -21.00
# Episode 323: Total Reward = -18.00
# Episode 324: Total Reward = -25.00
# Episode 325: Total Reward = -19.00
# Episode 326: Total Reward = -21.00
# Episode 327: Total Reward = -19.00
# Episode 328: Total Reward = -21.00
# Episode 329: Total Reward = -19.00
# Episode 330: Total Reward = -18.00
# Episode 331: Total Reward = -25.00
# Episode 332: Total Reward = -21.00
# Episode 333: Total Reward = -24.00
# Episode 334: Total Reward = -22.00
# Episode 335: Total Reward = -20.00
# Episode 336: Total Reward = -18.00
# Episode 337: Total Reward = -19.00
# Episode 338: Total Reward = -18.00
# Episode 339: Total Reward = -18.00
# Episode 340: Total Reward = -20.00
# Episode 341: Total Reward = -19.00
# Episode 342: Total Reward = -17.00
# Episode 343: Total Reward = -17.00
# Episode 344: Total Reward = -20.00
# Episode 345: Total Reward = -17.00
# Episode 346: Total Reward = -17.00
# Episode 347: Total Reward = -22.00
# Episode 348: Total Reward = -18.00
# Episode 349: Total Reward = -19.00
# Episode 350: Total Reward = -21.00
# Episode 351: Total Reward = -17.00
# Episode 352: Total Reward = -19.00
# Episode 353: Total Reward = -17.00
# Episode 354: Total Reward = -18.00
# Episode 355: Total Reward = -21.00
# Episode 356: Total Reward = -20.00
# Episode 357: Total Reward = -17.00
# Episode 358: Total Reward = -19.00
# Episode 359: Total Reward = -19.00
# Episode 360: Total Reward = -17.00
# Episode 361: Total Reward = -19.00
# Episode 362: Total Reward = -17.00
# Episode 363: Total Reward = -18.00
# Episode 364: Total Reward = -21.00
# Episode 365: Total Reward = -20.00
# Episode 366: Total Reward = -17.00
# Episode 367: Total Reward = -22.00
# Episode 368: Total Reward = -19.00
# Episode 369: Total Reward = -20.00
# Episode 370: Total Reward = -19.00
# Episode 371: Total Reward = -22.00
# Episode 372: Total Reward = -19.00
# Episode 373: Total Reward = -18.00
# Episode 374: Total Reward = -21.00
# Episode 375: Total Reward = -20.00
# Episode 376: Total Reward = -17.00
# Episode 377: Total Reward = -17.00
# Episode 378: Total Reward = -18.00
# Episode 379: Total Reward = -22.00
# Episode 380: Total Reward = -19.00
# Episode 381: Total Reward = -27.00
# Episode 382: Total Reward = -22.00
# Episode 383: Total Reward = -20.00
# Episode 384: Total Reward = -17.00
# Episode 385: Total Reward = -17.00
# Episode 386: Total Reward = -24.00
# Episode 387: Total Reward = -17.00
# Episode 388: Total Reward = -17.00
# Episode 389: Total Reward = -21.00
# Episode 390: Total Reward = -21.00
# Episode 391: Total Reward = -17.00
# Episode 392: Total Reward = -19.00
# Episode 393: Total Reward = -19.00
# Episode 394: Total Reward = -19.00
# Episode 395: Total Reward = -17.00
# Episode 396: Total Reward = -135.00
# Episode 397: Total Reward = -17.00
# Episode 398: Total Reward = -21.00
# Episode 399: Total Reward = -19.00
# Episode 400: Total Reward = -21.00
# Episode 401: Total Reward = -18.00
# Episode 402: Total Reward = -18.00
# Episode 403: Total Reward = -17.00
# Episode 404: Total Reward = -17.00
# Episode 405: Total Reward = -18.00
# Episode 406: Total Reward = -23.00
# Episode 407: Total Reward = -20.00
# Episode 408: Total Reward = -17.00
# Episode 409: Total Reward = -18.00
# Episode 410: Total Reward = -20.00
# Episode 411: Total Reward = -22.00
# Episode 412: Total Reward = -22.00
# Episode 413: Total Reward = -20.00
# Episode 414: Total Reward = -20.00
# Episode 415: Total Reward = -22.00
# Episode 416: Total Reward = -19.00
# Episode 417: Total Reward = -20.00
# Episode 418: Total Reward = -22.00
# Episode 419: Total Reward = -17.00
# Episode 420: Total Reward = -17.00
# Episode 421: Total Reward = -17.00
# Episode 422: Total Reward = -21.00
# Episode 423: Total Reward = -17.00
# Episode 424: Total Reward = -17.00
# Episode 425: Total Reward = -119.00
# Episode 426: Total Reward = -22.00
# Episode 427: Total Reward = -20.00
# Episode 428: Total Reward = -17.00
# Episode 429: Total Reward = -18.00
# Episode 430: Total Reward = -19.00
# Episode 431: Total Reward = -20.00
# Episode 432: Total Reward = -22.00
# Episode 433: Total Reward = -117.00
# Episode 434: Total Reward = -17.00
# Episode 435: Total Reward = -18.00
# Episode 436: Total Reward = -22.00
# Episode 437: Total Reward = -17.00
# Episode 438: Total Reward = -21.00
# Episode 439: Total Reward = -21.00
# Episode 440: Total Reward = -18.00
# Episode 441: Total Reward = -17.00
# Episode 442: Total Reward = -17.00
# Episode 443: Total Reward = -19.00
# Episode 444: Total Reward = -21.00
# Episode 445: Total Reward = -17.00
# Episode 446: Total Reward = -19.00
# Episode 447: Total Reward = -19.00
# Episode 448: Total Reward = -17.00
# Episode 449: Total Reward = -17.00
# Episode 450: Total Reward = -19.00
# Episode 451: Total Reward = -19.00
# Episode 452: Total Reward = -19.00
# Episode 453: Total Reward = -21.00
# Episode 454: Total Reward = -17.00
# Episode 455: Total Reward = -19.00
# Episode 456: Total Reward = -18.00
# Episode 457: Total Reward = -21.00
# Episode 458: Total Reward = -17.00
# Episode 459: Total Reward = -20.00
# Episode 460: Total Reward = -17.00
# Episode 461: Total Reward = -19.00
# Episode 462: Total Reward = -17.00
# Episode 463: Total Reward = -19.00
# Episode 464: Total Reward = -117.00
# Episode 465: Total Reward = -23.00
# Episode 466: Total Reward = -17.00
# Episode 467: Total Reward = -17.00
# Episode 468: Total Reward = -17.00
# Episode 469: Total Reward = -17.00
# Episode 470: Total Reward = -19.00
# Episode 471: Total Reward = -20.00
# Episode 472: Total Reward = -121.00
# Episode 473: Total Reward = -18.00
# Episode 474: Total Reward = -19.00
# Episode 475: Total Reward = -18.00
# Episode 476: Total Reward = -17.00
# Episode 477: Total Reward = -17.00
# Episode 478: Total Reward = -19.00
# Episode 479: Total Reward = -20.00
# Episode 480: Total Reward = -19.00
# Episode 481: Total Reward = -117.00
# Episode 482: Total Reward = -18.00
# Episode 483: Total Reward = -18.00
# Episode 484: Total Reward = -20.00
# Episode 485: Total Reward = -19.00
# Episode 486: Total Reward = -21.00
# Episode 487: Total Reward = -17.00
# Episode 488: Total Reward = -19.00
# Episode 489: Total Reward = -20.00
# Episode 490: Total Reward = -17.00
# Episode 491: Total Reward = -17.00
# Episode 492: Total Reward = -20.00
# Episode 493: Total Reward = -17.00
# Episode 494: Total Reward = -19.00
# Episode 495: Total Reward = -19.00
# Episode 496: Total Reward = -17.00
# Episode 497: Total Reward = -22.00
# Episode 498: Total Reward = -20.00
# Episode 499: Total Reward = -18.00
# Test Total Reward = -17.00
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
