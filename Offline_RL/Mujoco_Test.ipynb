# %%
import gymnasium as gym

# %%
env = gym.make('Hopper-v3')
# Out:
# /home/zhura/miniconda3/envs/torch/lib/python3.8/site-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment Hopper-v3 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(
# /home/zhura/miniconda3/envs/torch/lib/python3.8/site-packages/gymnasium/envs/mujoco/mujoco_env.py:211: DeprecationWarning: WARN: This version of the mujoco environments depends on the mujoco-py bindings, which are no longer maintained and may stop working. Please upgrade to the v4 versions of the environments (which depend on the mujoco python bindings instead), unless you are trying to precisely replicate previous works).
#   logger.deprecation(

# %%
print('Action space:', env.action_space)
print('Observation space:', env.observation_space)
# Out:
# Action space: Box(-1.0, 1.0, (3,), float32)
# Observation space: Box(-inf, inf, (11,), float64)
